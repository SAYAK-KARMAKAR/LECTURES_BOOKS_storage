# %%
from scipy import *
import numpy as np
from math import *
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import Image
#friends=['joseph','gleen', 'sally']
#print(friends)
#carryon=['socks','shirts','perfume']
#print(carryon)
#x=2
#x='hello'
#x=4
#print(x)
#print([1,24,76])
#print(['red','yellow','blue'])
#print([1,[5,6],7])
#print([])
#print(['red',24,98.6])
#for i in [5,4,3,2,1]:
#  print (i)
#print ('Blastoff!')
#friends=['joseph','gleen', 'sally']
#for friend in friends:
 # print ('Happy New Year', friend)
#print ('done')
#friends=['joseph' , 'gleen', 'sally']
#print(friends[1])
#fruit='Banana'
#fruit[0]='b'
#x=fruit.lower()
#print (x)
#lotto=[2,14,26,41,63]
#print (lotto)
#lotto[2]=28
#print (lotto)
# Out:
# c= [1, 2, 3, 4, 5, 6]
# d= [2, 3]
# e= [1, 2, 3, 2, 3]

# %%
lotto=[2,14,26,41,63]
print (lotto)
lotto[2]=28
print (lotto)

# %%
friends = ['joseph', 'gleen', 'sally']
for name in friends:
    print('HNY', name)

print('done')

# %%
#name=['joseph','gleen', 'sally']
#name[1]='raja'
#name[2]=90
#print(name)
#greet='hello bob'
#print (len(greet))
#x=[1,2,44.3,'joe']
#print (len(x))
print(range(4))
print (list(range(4)))
# Out:
# range(0, 4)
# [0, 1, 2, 3]

# %%
name=['joseph','gleen', 'sally']
print(len(name))
for i in range (len(name)):
  friend=name[i]
  print('happy new year:', friend)
# Out:
# 3
# happy new year: joseph
# happy new year: gleen
# happy new year: sally

# %%
a=[1,2,3]
b=[4,5,6]
c=a+b
d=[a[1],a[2]]
print(c)
print(d)
e=a+d
print(e)
t=[9,41,12,3,74,15]
print(t[1:3])
print(t[:4])
print(t[3:])
print(t[:])
print(t[::2]) #alternate terms
x=[1,2,3]
print(type(x))
dir(x)
stuff=list()
stuff.append('book')
stuff.append('99')
stuff.append('cookie')
print(stuff)
stuff[2]=' '
print(stuff)
some =[1,33,23,56]
print(9 in some)
print(9 not in some)
some.append(2)
print(some)
print(2 in some)
friends=['joseph','gleen', 'sally']
friends.sort()
print (friends)
numbers=[1, 89, 3, 12, 234]
numbers.sort()
numbers.remove(12)
print(numbers)
print(len(numbers))
print(max(numbers))
print (min(numbers))
print (sum(numbers))

# %%
friends=['joseph','gleen', 'sally']
friends.sort()
print (friends)
numbers=[1, 89, 3, 12, 234]
numbers.sort()
numbers.remove(12)
print(numbers)
print(len(numbers))
print(max(numbers))
print (min(numbers))
print (sum(numbers))
print (sum(numbers)/len(numbers))
# Out:
# ['gleen', 'joseph', 'sally']
# [1, 3, 89, 234]
# 4
# 234
# 1
# 327
# 81.75

# %%
some =[1,33,23,56]
print(9 in some)
print(9 not in some)
some.append(2)
print(some)
# Out:
# False
# True
# [1, 33, 23, 56, 2]

# %%
stuff=list()
stuff.append('book')
stuff.append('99')
stuff.append('cookie')
print(stuff)
stuff[2]=' '
print(stuff)
# Out:
# ['book', '99', 'cookie']
# ['book', '99', ' ']

# %%
x=[1,2,3]
print(type(x))
dir(x)
# Out:
# <class 'list'>
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
t=[9,41,12,3,74,15,5]
print(t[1:3])
print(t[:4])
print(t[3:])
print(t[:])
print(t[::2]) #alternate terms
print(t[::3]) #every third terms
# Out:
# [41, 12]
# [9, 41, 12, 3]
# [3, 74, 15, 5]
# [9, 41, 12, 3, 74, 15, 5]
# [9, 12, 74, 5]
# [9, 3, 5]

# %%
a=[1,2,3]
b=[4,5,6]
c=a+b
d=[a[1],a[2]]
e=a+d
print('c=',c)
print('d=',d)
print('e=',e)
# Out:
# c= [1, 2, 3, 4, 5, 6]
# d= [2, 3]
# e= [1, 2, 3, 2, 3]

# %%
import numpy as np

a = np.array([1, 2, 3])
b = np.array([4, 5, 6])
c = a + b
print('c=',c)
# Out:
# c= [5 7 9]

# %%
abc='with three words'
stuff=abc.split()
print(stuff)
print(len(stuff))
print(stuff[0])
line='A lot of       spaces'
etc=line.split()
print(etc)
line='with;three;words'
thing=line.split()
print(thing)
print(len(thing))
# Out:
# ['with', 'three', 'words']
# 3
# with
# ['A', 'lot', 'of', 'spaces']
# ['with;three;words']
# 1

# %%
New='with;three;words'
thing=New.split()
print(thing)
print(len(thing))
# Out:
# ['with;three;words']
# 1

# %%
line='A lot of       spaces'
etc=line.split()
print(etc)
# Out:
# ['A', 'lot', 'of', 'spaces']

# %%
abc='with three words'
stuff=abc.split()
print(stuff)
print(len(stuff))
print(stuff[0])
# Out:
# ['with', 'three', 'words']
# 3
# with

# %%
from scipy import *
import numpy as np
from math import *
import pandas as pd
import matplotlib.pyplot as plt
mnode=5
nnode=5
Lx=1
Ly=1
delta_x=Lx/(mnode-1)
delta_y=Ly/(nnode-1)
x=np.linspace(0,1,mnode)
y=np.linspace(0,1,nnode)
#print(y)
alphax=1/(delta_x)**2
#print(alphax)
alphay=1/(delta_y)**2
mnnode=mnode*nnode
A=np.zeros((mnnode,mnnode))
#print(A)
r=np.zeros((mnnode,1))
#print(r)
for j in range(0, nnode-1):
    for i in range(0, mnode-1):
      l=i+j*mnode;
      if i == 0 and j in range(1,mnode-2):
        A[l,l]=1
        r[l]=10
      elif i in range(1,nnode-2) and j==0:
        A[l,l]=1
        r[l]=100
      elif i in range(1,nnode-2) and j==(mnode-1):
        A[l,l]=1
        r[l]=50
      elif i==(nnode-1) and j in range(1,mnode-2):
        A[l,l]=1
        r[l]=10
      elif i==0 and j==0:
        A[l,l]=1
        r[l]=100
      elif i==0 and j==mnode-1:
        A[l,l]=1
        r[l]=50
      elif i==nnode-1 and j==0:
        A[l,l]=1
        r[l]=100
      elif i==nnode-1 and j==mnode-1:
        A[l,l]=1
        r[l]=50
      else:
        A[l,l-mnode]=alphay
        A[l,l-1]=alphax
        A[l,l]=-2*(alphax+alphay)
        A[l,l+1]=alphax
        A[l,l+mnode]=alphay
        r[l]=sin(x[l]+y[l])
      T= np.linalg.solve(A,r)
      print(T)





    print(A)
    print(r)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-25-848723df9e58> in <cell line: 23>()
#      55         A[l,l+mnode]=alphay
#      56         r[l]=sin(x[l]+y[l])
# ---> 57       T= np.linalg.solve(A,r)
#      58       print(T)
#      59
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/overrides.py in solve(*args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/numpy/linalg/linalg.py in solve(a, b)
#     398     signature = 'DD->D' if isComplexType(t) else 'dd->d'
#     399     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 400     r = gufunc(a, b, signature=signature, extobj=extobj)
#     401
#     402     return wrap(r.astype(result_t, copy=False))
#
# /usr/local/lib/python3.10/dist-packages/numpy/linalg/linalg.py in _raise_linalgerror_singular(err, flag)
#      87
#      88 def _raise_linalgerror_singular(err, flag):
# ---> 89     raise LinAlgError("Singular matrix")
#      90
#      91 def _raise_linalgerror_nonposdef(err, flag):
#
# LinAlgError: Singular matrix

# %%
# @title
from scipy import *
import numpy as np
from math import *
import pandas as pd
import matplotlib.pyplot as plt

mnode = 5
nnode = 5
Lx = 1
Ly = 1
delta_x = Lx / (mnode - 1)
delta_y = Ly / (nnode - 1)
x = np.linspace(0, 1, mnode)
y = np.linspace(0, 1, nnode)
#print(y)
alphax = 1 / (delta_x) ** 2
#print(alphax)
alphay = 1 / (delta_y) ** 2
mnnode = mnode * nnode
A = np.zeros((mnnode, mnnode))
#print(A)
r = np.zeros((mnnode, 1))
#print(r)
for j in range(0, nnode):
    for i in range(0, mnode):
        l = i + j * mnode
        if i == 0 and j in range(1, mnode-1):
            A[l, l] = 1
            r[l] = 10
        elif i in range(1, nnode-1) and j == 0:
            A[l, l] = 1
            r[l] = 100
        elif i in range(1, nnode-1) and j == (mnode - 1):
            A[l, l] = 1
            r[l] = 50
        elif i == (nnode - 1) and j in range(1, mnode - 1):
            A[l, l] = 1
            r[l] = 10
        elif i == 0 and j == 0:
            A[l, l] = 1
            r[l] = 100
        elif i == 0 and j == mnode - 1:
            A[l, l] = 1
            r[l] = 50
        elif i == nnode - 1 and j == 0:
            A[l, l] = 1
            r[l] = 100
        elif i == nnode - 1 and j == mnode - 1:
            A[l, l] = 1
            r[l] = 50
        else:
            A[l, l - mnode] = alphay
            A[l, l - 1] = alphax
            A[l, l] = -2 * (alphax + alphay)
            A[l, l + 1] = alphax
            A[l, l + mnode] = alphay
            r[l] = sin(x[i] + y[j])

T = np.linalg.solve(A, r)

# %%
from scipy import *
import numpy as np
from math import *
import pandas as pd
import matplotlib.pyplot as plt

mnode = 5
nnode = 5
Lx = 1
Ly = 1
delta_x = Lx / (mnode - 1)
delta_y = Ly / (nnode - 1)
x = np.linspace(0, 1, mnode)
y = np.linspace(0, 1, nnode)
#print(y)
alphax = 1 / (delta_x) ** 2
#print(alphax)
alphay = 1 / (delta_y) ** 2
mnnode = mnode * nnode
A = np.zeros((mnnode, mnnode))
#print(A)
r = np.zeros((mnnode, 1))
#print(r)
for j in range(0, 5):
    for i in range(0, 5):
        l = i + j * 5
        if i == 0 and j in range(1, 4):
            A[l, l] = 1
            r[l] = 10
        elif i in range(1, 4) and j == 0:
            A[l, l] = 1
            r[l] = 100
        elif i in range(1, 4) and j == 4:
            A[l, l] = 1
            r[l] = 50
        elif i == 4 and j in range(1,4):
            A[l, l] = 1
            r[l] = 10
        elif i == 0 and j == 0:
            A[l, l] = 1
            r[l] = 100
        elif i == 0 and j == 4:
            A[l, l] = 1
            r[l] = 50
        elif i == 4 and j == 0:
            A[l, l] = 1
            r[l] = 100
        elif i == 4 and j == 4:
            A[l, l] = 1
            r[l] = 50
        else:
            A[l, l - mnode] = alphay
            A[l, l - 1] = alphax
            A[l, l] = -2 * (alphax + alphay)
            A[l, l + 1] = alphax
            A[l, l + mnode] = alphay
            r[l] = sin(x[i] + y[j])

T = np.linalg.solve(A, r)
print(T)
# Out:
# [[100.        ]
#  [100.        ]
#  [100.        ]
#  [100.        ]
#  [100.        ]
#  [ 10.        ]
#  [ 51.40065427]
#  [ 61.29843344]
#  [ 51.3932256 ]
#  [ 10.        ]
#  [ 10.        ]
#  [ 34.33414773]
#  [ 42.44245632]
#  [ 34.32706088]
#  [ 10.        ]
#  [ 10.        ]
#  [ 33.53608274]
#  [ 39.86277517]
#  [ 33.53187315]
#  [ 10.        ]
#  [ 50.        ]
#  [ 50.        ]
#  [ 50.        ]
#  [ 50.        ]
#  [ 50.        ]]

# %%
#
from scipy import *
import numpy as np
from math import *
import pandas as pd
import matplotlib.pyplot as plt

mnode = 5
nnode = 5
Lx = 1
Ly = 1
delta_x = Lx / (mnode - 1)
delta_y = Ly / (nnode - 1)
x = np.linspace(0, 1, mnode)
y = np.linspace(0, -1, nnode)
#print(y)
alphax = 1 / (delta_x) ** 2
#print(alphax)
alphay = 1 / (delta_y) ** 2
mnnode = mnode * nnode
A = np.zeros((mnnode, mnnode))
#print(A)
r = np.zeros((mnnode, 1))
#print(r)
for j in range(0, nnode):
    for i in range(0, mnode):
        l = i + j * mnode
        if i == 0 and j in range(1, mnode-1):
            A[l, l] = 1
            r[l] = 10
        elif i in range(1, nnode-1) and j == 0:
            A[l, l] = 1
            r[l] = 100
        elif i in range(1, nnode-1) and j == (mnode - 1):
            A[l, l] = 1
            r[l] = 50
        elif i == (nnode - 1) and j in range(1, mnode - 1):
            A[l, l] = 1
            r[l] = 10
        elif i == 0 and j == 0:
            A[l, l] = 1
            r[l] = 100
        elif i == 0 and j == mnode - 1:
            A[l, l] = 1
            r[l] = 50
        elif i == nnode - 1 and j == 0:
            A[l, l] = 1
            r[l] = 100
        elif i == nnode - 1 and j == mnode - 1:
            A[l, l] = 1
            r[l] = 50
        else:
            A[l, l - mnode] = alphay
            A[l, l - 1] = alphax
            A[l, l] = -2 * (alphax + alphay)
            A[l, l + 1] = alphax
            A[l, l + mnode] = alphay
            r[l] = sin(x[i] + y[j])

T = np.linalg.solve(A, r)
#print(T)
Temp=np.zeros((mnode,nnode))
for j in range(0,nnode):
  for i in range(0,mnode):
    Temp[i,j]=T[i+j*nnode]
print('Temp=',Temp)

plt.contourf(x,y,Temp)
plt.colorbar()
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Spatial Distribution of Temperature in Square Plate')
plt.show()
# Out:
# Temp= [[100.          10.          10.          10.          50.        ]
#  [100.          51.42857143  34.38155822  33.58219871  50.        ]
#  [100.          61.33272749  42.5         39.91727251  50.        ]
#  [100.          51.41780129  34.36844178  33.57142857  50.        ]
#  [100.          10.          10.          10.          50.        ]]

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a grid of data
x = np.linspace(0, 10, 100)
y = np.linspace(0, 10, 100)
z = np.random.rand(100, 100)

# Create a colormap
cmap = plt.cm.jet

# Plot the grid data
plt.pcolor(x, y, z, cmap=cmap)

# Set the axes labels
plt.xlabel('X')
plt.ylabel('Y')

# Show the plot
plt.show()
